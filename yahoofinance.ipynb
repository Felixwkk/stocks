
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2020-04-13  164.35  165.57  162.30  165.51  41905300          0             0
# 2020-04-14  169.00  173.75  168.00  173.70  52874300          0             0
# 2020-04-15  171.20  173.57  169.24  171.88  40940800          0             0
# 2020-04-16  174.30  177.28  172.90  177.04  50479600          0             0
# 2020-04-17  179.50  180.00  175.87  178.60  52765600          0             0
# 2020-04-20  176.63  178.75  174.99  175.06  36669600          0             0
# 2020-04-21  173.50  173.67  166.11  167.82  56203700          0             0
# 2020-04-22  171.39  174.00  170.82  173.52  34651600          0             0
# 2020-04-23  174.11  175.06  170.91  171.42  32790800          0             0
# 2020-04-24  172.06  174.56  170.71  174.55  34305300          0             0
# 2020-04-27  176.59  176.90  173.30  174.05  33194400          0             0
# ...

# %%
! pip install feedparser

# %%
finance_url  ='https://finance.yahoo.com/rss/topstories'
cna_url ='https://www.channelnewsasia.com/rssfeeds/8395986'
cna_bus_url = 'https://www.channelnewsasia.com/rssfeeds/8395954'
import feedparser
info = feedparser.parse(finance_url)
info2 = feedparser.parse(cna_url)
info3 = feedparser.parse(cna_bus_url)

# %%
len(info)
# Out:
# 12

# %%
 info.feed.title
# Out:
# 'Yahoo Finance'

# %%
for entry in info.entries:
  print( entry)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-2c4e8195dcde> in <module>()
# ----> 1 for entry in info.entries:
#       2   print( entry)
#
# AttributeError: 'dict' object has no attribute 'entries'

# %%
entry = info.entries[0]
entry.title
# Out:
# 'U.S. Stocks Slump After Fauci, Fed Set Somber Tone: Markets Wrap'

# %%
entry.title_detail
# Out:
# {'base': 'https://finance.yahoo.com/rss/topstories',
#  'language': None,
#  'type': 'text/plain',
#  'value': 'U.S. Stocks Slump After Fauci, Fed Set Somber Tone: Markets Wrap'}

# %%
entry.link
# Out:
# 'https://finance.yahoo.com/news/why-cashed-covid-19-rally-040028323.html'

# %%
entry.published
# Out:
# 'Tue, 12 May 2020 00:00:28 -0400'

# %%
for entry in info.entries:
  print( entry.title)
# Out:
# U.S. Stocks Slump After Fauci, Fed Set Somber Tone: Markets Wrap
# U.S. natgas output, demand to fall in 2020, 2021 due to coronavirus
# Why I Cashed Out of the Covid-19 Rally
# 2 Cruise Line Stocks to Bet on After the Coronavirus Crisis (And 1 to Avoid)
# Steak &#39;n Shake permanently closing 57 restaurants amid coronavirus pandemic
# Nightmare at Sea Ends in Death for Some Cruise-Ship Workers
# High-yield savings banks finally hit by the Fed&#39;s coronavirus rate cut
# Column: Does Elon Musk need California more than California needs Elon Musk?
# Apple stock rises after iPhone 12 details revealed
# Richard Branson Scrambles to Save His Flailing Virgin Empire
# Stocks - Wall Street Reverses Early Gains as Trump Hits Bank Stocks
# Could Musk's recent comments hurt Tesla sales?
# IRS issues deadline for direct deposit info for coronavirus stimulus payments
# 3 Biotech Stocks Under $3 With 200%-Plus Upside Potential
# Mortgage Rates Seen Below 3% With Fed Buying Low-Coupon Bonds
# ...

# %%
key_word = 'covid'
for entry in info.entries:
    if key_word in entry.title.lower():
      print(entry.title)
# Out:
# Why I Cashed Out of the Covid-19 Rally
# Moderna’s Covid-19 Vaccine Candidate Gets FDA Fast Track Status

# %%
key_word = 'stocks'
for entry in info.entries:
    if key_word in entry.title.lower():
      print(entry.title)
# Out:
# U.S. Stocks Slump After Fauci, Fed Set Somber Tone: Markets Wrap
# 2 Cruise Line Stocks to Bet on After the Coronavirus Crisis (And 1 to Avoid)
# Stocks - Wall Street Reverses Early Gains as Trump Hits Bank Stocks
# 3 Biotech Stocks Under $3 With 200%-Plus Upside Potential
# Wells Fargo: 2 Big 16% Dividend Stocks to Buy (And 1 to Avoid)
# Investors Are Dumping Stocks for Bonds as Fed Buying Begins
# Stock market news live updates: Stocks post worst drop in seven sessions; Grubhub spikes on takeover reports
# Goldman Says Stocks Due for 18% Drop After Rally Driven by FOMO

# %%
len(info2)
# Out:
# 9

# %% [markdown]
# CHannel news Asia Feeds

# %%
info2.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
info2.values()
# Out:
# dict_values([{'language': 'en-US', 'title': 'Latest News', 'title_detail': {'type': 'text/plain', 'language': 'en-US', 'base': 'https://www.channelnewsasia.com/rssfeeds/8395986', 'value': 'Latest News'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.channelnewsasia.com'}], 'link': 'https://www.channelnewsasia.com', 'subtitle': 'mediacorp feed news', 'subtitle_detail': {'type': 'text/html', 'language': 'en-US', 'base': 'https://www.channelnewsasia.com/rssfeeds/8395986', 'value': 'mediacorp feed news'}, 'updated': 'Wed, 13 May 2020 07:38:55 +0800', 'updated_parsed': time.struct_time(tm_year=2020, tm_mon=5, tm_mday=12, tm_hour=23, tm_min=38, tm_sec=55, tm_wday=1, tm_yday=133, tm_isdst=0), 'generator_detail': {'name': 'Mediacorp'}, 'generator': 'Mediacorp', 'ttl': '100', 'image': {'href': 'https://www.channelnewsasia.com/image/8395694/1x1/114/114/eb06a179c414e4534ff4417b64f3710c/kC/apple-touch-icon.png', 'title': 'Latest News', 'title_detail': {'type': 'text/pl
# ...

# %%
for entry in info2.entries:
    print(entry)
# Out:
# {'id': 'https://www.channelnewsasia.com/news/sport/tests-and-more-tests-for-players-as-pga-tour-prepares-for-return-12726612', 'guidislink': False, 'title': 'Tests and more tests for players as PGA Tour prepares for return', 'title_detail': {'type': 'text/plain', 'language': 'en-US', 'base': 'https://www.channelnewsasia.com/rssfeeds/8395986', 'value': 'Tests and more tests for players as PGA Tour prepares for return'}, 'links': [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://www.channelnewsasia.com/news/sport/tests-and-more-tests-for-players-as-pga-tour-prepares-for-return-12726612'}], 'link': 'https://www.channelnewsasia.com/news/sport/tests-and-more-tests-for-players-as-pga-tour-prepares-for-return-12726612', 'summary': 'REUTERS: Golfers and caddies returning to the PGA Tour next month will face a battery of tests and safety measures as they adjust to tournament golf in the era of novel coronavirus.\n\nGolf Channel said on Tuesday it had seen the 37-page health and safe
# ...

# %% [markdown]
# Latest news CNA

# %%
for entry in info2.entries:
    print(entry.title)
# Out:
# Tests and more tests for players as PGA Tour prepares for return
# The US needs more fiscal help to fight coronavirus, Fed officials say
# Tennis: Serena eager to return after lockdown break
# Premier League players face strict new training protocols
# Charity drive: How BMW is supporting Malaysia’s underprivileged during MCO
# As Paris's coronavirus lockdown eases, luxury stores test the water
# Yoga aunties, cheesecake cravings: A week in the life of someone stuck at home
# Is that face mask causing your sensitive skin to break out? A doctor's helpful tips
# Fancy a FaceTime photoshoot? Photographers get creative amid circuit-breaker measures
# With only one toilet and limited water, refugee in cramped Jakarta shelter fears COVID-19 spread
# ‘The whole of Singapore coming together’: Local firms team up to distribute 100,000 COVID-19 care packs to vulnerable households
# Commentary: COVID-19 treatment researchers should be cooperating not trash-talking each other
# ...

# %% [markdown]
# Business News CNA

# %%
for entry in info3.entries:
    print(entry.title)
# Out:
# The US needs more fiscal help to fight coronavirus, Fed officials say
# ‘The whole of Singapore coming together’: Local firms team up to distribute 100,000 COVID-19 care packs to vulnerable households
# Commentary: Globalisation is facing a third strike-and-out scenario
# Commentary: Were you fired or retrenched? Your employer may not tell you the difference
# US stocks close lower, ending Nasdaq streak with 2.1% fall
# KKR leads US$43 million investment round in Slice pizza platform
# Twitter to let some employees to work from home permanently
# COVID-19: India PM announces US$270b economic package
# Starbucks rival Luckin Coffee fires CEO in fraud scandal
# US posts record US$738 billion budget deficit in April
# Waymo extends external funding round to US$3 billion
# US attorneys general ask Amazon for data on COVID-19-linked worker deaths, infections
# US attorneys general ask Amazon for data on COVID-19-linked worker deaths, infections
# ...

# %% [markdown]
# Filtering due to keywords

# %%
key_word = ['virus','covid']
for entry in info3.entries:
  if key_word[0] in entry.title or key_word[1] in entry.title:
    print(entry.title)
# Out:
# The US needs more fiscal help to fight coronavirus, Fed officials say
# Chinese coronavirus vaccine could be tested, manufactured in Canada
# Democratic presidential candidate Biden warns against coronavirus stimulus corruption
# UK leaves coronavirus lifeline for workers in place for 4 more months
# S&P 500 ends lower on fears of virus resurgence in economic reopening
# US Congress presses bank regulators on coronavirus assistance, oversight
# China's Tesla wannabes risk running out of road in virus-stricken times
# Popeyes sticks to China expansion plan in spite of virus
# South Korea investigators comb digital data to trace club coronavirus cluster
# Toyota sees 80% profit drop as virus wipes US$14 billion off car sales
# Stocks rally falters as virus and trade nerves linger
# Thyssenkrupp second-quarter loss widens as coronavirus impact starts to show
# US dollar hits 2-week peak as 'second wave' virus fears drive safe-haven bid
# ...
